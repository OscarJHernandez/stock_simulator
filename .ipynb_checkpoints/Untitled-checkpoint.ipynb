# %%
import numpy as np
import matplotlib.pyplot as plt
import stock_sims as st

# %%
S1=st.stock_simulator(mu=-0.001,sigma=0.03)
S2=st.stock_simulator(mu=0.001,sigma=0.03)

# %%
T = 1300
vN = []
VN50 = []
for i in range(0,100):
    v1=S1.simulate_stock(steps=T)
    v2=S2.simulate_stock(steps=T)
    vN.append(v1[-1])
    #plt.plot(v1,color="red")
    plt.plot(v2,color="green")
